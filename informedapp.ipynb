# %%
import numpy as np
import pandas as pd

df = pd.read_csv("sfpd_incident_reports.csv")

df.head()
# Out:
#   incident_datetime incident_date incident_time  incident_year incident_dow  \
# 0     1/1/2018 8:00      1/1/2018          8:00           2018       Monday
# 1     1/1/2018 0:00      1/1/2018          0:00           2018       Monday
# 2     1/1/2018 0:00      1/1/2018          0:00           2018       Monday
# 3    1/1/2018 14:30      1/1/2018         14:30           2018       Monday
# 4    1/1/2018 18:00      1/1/2018         18:00           2018       Monday
#
#    report_datetime        row_id  Incident ID  incident_number   cad_number  \
# 0  1/17/2019 15:38  7.602503e+10       760250        190041467  190172598.0
# 1   2/8/2019 18:06  7.680483e+10       768048        190098123  190392939.0
# 2  1/24/2019 16:25  7.627171e+10       762717        190059824  190242941.0
# 3   1/2/2018 17:40  6.199473e+10       619947        186001558          NaN
# 4   1/2/2019 17:25  7.549681e+10       754968        190004487  190022887.0
#
#    ...   incident_category incident_subcategory  \
# ...
